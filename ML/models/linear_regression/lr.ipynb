# %%
import pandas as pd
import numpy as np
dict={'1':[1,456],'2':[2,154],'3':[3,654],'4':[4,15]}
df=pd.DataFrame(dict)
s=np.random.rand(len(df))<0.8
print(s,df[s],sep='\n')
# Out:
# [ True False]
#    1  2  3  4
# 0  1  2  3  4

# %%
df=pd.read_csv(r"C:\Users\mutte\OneDrive\Desktop\cricket dataset\Batting\test.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                Player       Span  Mat Inns  NO   Runs    HS  \
# 0           0  SR Tendulkar (INDIA)  1989-2013  200  329  33  15921  248*
# 1           1      RT Ponting (AUS)  1995-2012  168  287  29  13378   257
# 2           2    JH Kallis (ICC/SA)  1995-2013  166  280  40  13289   224
# 3           3  R Dravid (ICC/INDIA)  1996-2012  164  286  32  13288   270
# 4           4         AN Cook (ENG)  2006-2018  161  291  16  12472   294
#
#      Ave 100  50   0  Unnamed: 11
# 0  53.78  51  68  14          NaN
# 1  51.85  41  62  17          NaN
# 2  55.37  45  58  16          NaN
# 3  52.31  36  63   8          NaN
# 4  45.35  33  57   9          NaN

# %%
from sklearn import linear_model

# %%
import numpy as np
km=np.random.rand(len(df))<0.8
train=df[km]
test=df[~km]

# %%
#print(train,test)
lm=linear_model.LinearRegression()

# %%
train_x=np.asarray(train['Mat']).reshape(-1,1)
train_y=np.asarray(train['Inns']).reshape(-1,1)
lm.fit(train_x,train_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 train_x=np.asarray(train['Mat']).reshape(-1,1)
#       2 train_y=np.asarray(train['Inns']).reshape(-1,1)
# ----> 3 lm.fit(train_x,train_y)
#
# File c:\Users\mutte\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\mutte\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:609, in LinearRegression.fit(self, X, y, sample_weight)
#     605 n_jobs_ = self.n_jobs
# ...

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model 
lr=linear_model.LinearRegression()
df=pd.read_csv(r'D:\swastik\ML\datasets\FuelConsumption (linear regression).csv')
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
km=np.random.rand(len(df)) < 0.75
newdf=df[['ENGINESIZE',	'CYLINDERS',	'TRANSMISSION',	'FUELTYPE',	'FUELCONSUMPTION_CITY','CO2EMISSIONS']]
train=newdf[km]
test=newdf[~km]

# %%
train_x=np.asanyarray(train['ENGINESIZE']).reshape(-1, 1)
train_y=np.asanyarray(train['CO2EMISSIONS'])

# %%
lr.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([38.53655202])

# %%
lr.intercept_
# Out:
# 127.37211531754608

# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\mutte\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
plt.scatter(train['ENGINESIZE'], train['CO2EMISSIONS'],  color='blue')
plt.plot(train_x, lr.coef_*train_x + lr.intercept_, '-r')
plt.xlabel("Engine size")
plt.ylabel("Emission")
# Out:
# Text(0, 0.5, 'Emission')

# %%
from sklearn import linear_model
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
lr=linear_model.LinearRegression()
df=pd.read_csv(r'D:\swastik\ML\datasets\FuelConsumption (linear regression).csv')
newdf=df[['ENGINESIZE','CO2EMISSIONS']]
rr=np.random.rand(len(df))<0.8
train=newdf[rr]
test=newdf[~rr]
train_x=np.asanyarray(train[['ENGINESIZE']])
train_y=np.asanyarray(train[['CO2EMISSIONS']])
lr.fit(train_x,train_y)
print(lr.coef_,lr.intercept_)
# Out:
# [[39.38714515]] [124.83766547]

# %%
test_x=np.asanyarray(test[['ENGINESIZE']])
test_y=np.asanyarray(test[['CO2EMISSIONS']])
test_y_= lr.predict(test_x)

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import r2_score

print("Mean absolute error: %.2f" %np.mean(np.absolute(test_y-test_y_)) )
print("Residual sum of squares (MSE): %.2f" %np.mean((test_y-test_y_)**2) )
print("R2-score: %.2f" % r2_score(test_y , test_y_) )
# Out:
# Mean absolute error: 23.22
# Residual sum of squares (MSE): 941.89
# R2-score: 0.76

# %%
plt.plot(test_y,label='True',color='blue')
plt.plot(test_y_,label='Pred',color='red')
plt.title('true and pred')
plt.legend()
